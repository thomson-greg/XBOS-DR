# %%
import matplotlib.pyplot as plt
import pickle

# %%
with open("params", 'r') as f:
    data = pickle.load(f)

# %%
temp = data["HVAC_Zone_Northzone"]
for i in temp:
    print(i)
    print("/n")
# Out:
# [ 0.03944697 -0.1325248   0.00108189  0.02275017  0.00066806  0.00089721
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00197194  0.02230515  0.00066806  0.00129773
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00274564  0.0219183   0.00066806  0.0016459
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.0034182   0.02158202  0.00066806  0.00194855
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00400284  0.0212897   0.00066806  0.00221163
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00451105  0.02103559  0.00066806  0.00244033
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00495282  0.02081471  0.00066806  0.00263913
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00533684  0.0206227   0.00066806  0.00281194
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00567067  0.02045578  0.00066806  0.00296216
#  -0.00020095]
# /n
# [ 0.03944697 -0.1325248   0.00596085  0.02031069  0.00066806  0.00309274
#  -0.00020095]
# /n
# ...

# %%
import numpy as np

# %%
a = np.array([[1,2], [4,5]])
b = np.array([4,10])
a * b
# Out:
# array([[ 4, 20],
#        [16, 50]])

# %%
np.array(a)
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
a[0]
# Out:
# array([1, 2])

# %%
t = np.array(np.array(a))

# %%
k = [[1,2], [4,5]]

# %%
a = np.array([[1], [2]])
b = np.array([1, 2])
a.reshape((a.shape[0])) - b
# Out:
# array([0, 0])

# %%
a = [1]

# %%
a[-50:]
# Out:
# [1]

# %%
def myround(x, base=0.05):
    return base * round(float(x)/base)
s = 0.17
t = 0.15 
s1 = 0.54
t = 0.55
myround(s, base=0.05)
# Out:
# 0.15000000000000002

# %%
round(0.17/0.05)
# Out:
# 3.0

# %%
3 * 0.05
# Out:
# 0.15000000000000002
